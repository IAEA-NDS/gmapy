# %% [markdown]
# # Plotting of GMAP results
#
# This notebook shows how to do a fit with the `gmapy` package and plot some results afterwards.
#
# **NOTE: Plotting code at the end broken for some reason.**
#
#
# ## Load necessary libraries

# %%
import sys
sys.path.append('..')  # so that gmapy can be found
import numpy as np
import pandas as pd
from numpy.random import default_rng
import matplotlib.pyplot as plt
from gmapy.legacy.legacy_gmap import run_gmap
from gmapy.mappings.compound_map import CompoundMap
dbfile = '../tests/testdata/data-2017-07-26.gma'

# %% [markdown]
# ## Perform the fit

# %%
# %%capture
res = run_gmap(dbfile, dbtype='legacy', num_iter=3, fix_ppp_bug=True, fix_sacs_jacobian=True, legacy_output=False)

# %% [markdown]
# ## Examine the result data
#
# The dictionary returned by `run_gmap` contains a `table` field, which contains a dataframe with the information to be plotted. Let's have a look at this dataframe:

# %%
resdf = res['table']
resdf[(resdf.ENERGY > 0) & (resdf.ENERGY < 0.001) & (resdf.REAC == 'MT:1-R1:1')]
# Out:
#           NODE       REAC        ENERGY       PRIOR  UNC     DESCR  \
# 0       xsid_1  MT:1-R1:1  2.530000e-08  938.131177  inf  6Li(n,a)
# 1       xsid_1  MT:1-R1:1  9.400000e-06   48.639696  inf  6Li(n,a)
# 2       xsid_1  MT:1-R1:1  1.500000e-04   12.160772  inf  6Li(n,a)
# 3       xsid_1  MT:1-R1:1  2.500000e-04    9.413054  inf  6Li(n,a)
# 4       xsid_1  MT:1-R1:1  3.500000e-04    7.951949  inf  6Li(n,a)
# 5       xsid_1  MT:1-R1:1  4.500000e-04    7.010730  inf  6Li(n,a)
# 6       xsid_1  MT:1-R1:1  5.500000e-04    6.340275  inf  6Li(n,a)
# 7       xsid_1  MT:1-R1:1  6.500000e-04    5.830441  inf  6Li(n,a)
# 8       xsid_1  MT:1-R1:1  7.500000e-04    5.427131  inf  6Li(n,a)
# 9       xsid_1  MT:1-R1:1  8.500000e-04    5.096999  inf  6Li(n,a)
# 10      xsid_1  MT:1-R1:1  9.500000e-04    4.820209  inf  6Li(n,a)
# 4649   exp_900  MT:1-R1:1  2.530000e-08         NaN  NaN       NaN
# 4650   exp_900  MT:1-R1:1  9.400000e-06         NaN  NaN       NaN
# 4651   exp_900  MT:1-R1:1  1.500000e-04         NaN  NaN       NaN
# 4652   exp_900  MT:1-R1:1  2.500000e-04         NaN  NaN       NaN
# 4653   exp_900  MT:1-R1:1  3.500000e-04         NaN  NaN       NaN
# 4654   exp_900  MT:1-R1:1  4.500000e-04         NaN  NaN       NaN
# 4655   exp_900  MT:1-R1:1  5.500000e-04         NaN  NaN       NaN
# 4656   exp_900  MT:1-R1:1  6.500000e-04         NaN  NaN       NaN
# 4657   exp_900  MT:1-R1:1  7.500000e-04         NaN  NaN       NaN
# 4658   exp_900  MT:1-R1:1  8.500000e-04         NaN  NaN       NaN
# 4659   exp_900  MT:1-R1:1  9.500000e-04         NaN  NaN       NaN
# 8002  exp_2001  MT:1-R1:1  2.530000e-08         NaN  NaN       NaN
# 8003  exp_2001  MT:1-R1:1  9.400000e-06         NaN  NaN       NaN
# 8004  exp_2001  MT:1-R1:1  1.500000e-04         NaN  NaN       NaN
# 8005  exp_2001  MT:1-R1:1  2.500000e-04         NaN  NaN       NaN
# 8006  exp_2001  MT:1-R1:1  3.500000e-04         NaN  NaN       NaN
# 8007  exp_2001  MT:1-R1:1  4.500000e-04         NaN  NaN       NaN
# 8008  exp_2001  MT:1-R1:1  5.500000e-04         NaN  NaN       NaN
# 8009  exp_2001  MT:1-R1:1  6.500000e-04         NaN  NaN       NaN
# 8010  exp_2001  MT:1-R1:1  7.500000e-04         NaN  NaN       NaN
# 8011  exp_2001  MT:1-R1:1  8.500000e-04         NaN  NaN       NaN
# 8012  exp_2001  MT:1-R1:1  9.500000e-04         NaN  NaN       NaN
#
#             DATA  DB_IDX  DS_IDX                            AUTHOR  \
# 0            NaN     NaN     NaN                               NaN
# 1            NaN     NaN     NaN                               NaN
# 2            NaN     NaN     NaN                               NaN
# 3            NaN     NaN     NaN                               NaN
# 4            NaN     NaN     NaN                               NaN
# 5            NaN     NaN     NaN                               NaN
# 6            NaN     NaN     NaN                               NaN
# 7            NaN     NaN     NaN                               NaN
# 8            NaN     NaN     NaN                               NaN
# 9            NaN     NaN     NaN                               NaN
# 10           NaN     NaN     NaN                               NaN
# 4649  938.131177   107.0     0.0                             DUMMY
# 4650   48.639696   107.0     0.0                             DUMMY
# 4651   12.160772   107.0     0.0                             DUMMY
# 4652    9.413054   107.0     0.0                             DUMMY
# 4653    7.951949   107.0     0.0                             DUMMY
# 4654    7.010730   107.0     0.0                             DUMMY
# 4655    6.340275   107.0     0.0                             DUMMY
# 4656    5.830441   107.0     0.0                             DUMMY
# 4657    5.427131   107.0     0.0                             DUMMY
# 4658    5.096999   107.0     0.0                             DUMMY
# 4659    4.820209   107.0     0.0                             DUMMY
# 8002  938.525000   217.0     1.0  G.Hale+Chen Zhenpeng - (EDA+RAC)
# 8003   48.660000   217.0     1.0  G.Hale+Chen Zhenpeng - (EDA+RAC)
# 8004   12.163000   217.0     1.0  G.Hale+Chen Zhenpeng - (EDA+RAC)
# 8005    9.415000   217.0     1.0  G.Hale+Chen Zhenpeng - (EDA+RAC)
# 8006    7.953500   217.0     1.0  G.Hale+Chen Zhenpeng - (EDA+RAC)
# 8007    7.012000   217.0     1.0  G.Hale+Chen Zhenpeng - (EDA+RAC)
# 8008    6.341200   217.0     1.0  G.Hale+Chen Zhenpeng - (EDA+RAC)
# 8009    5.831300   217.0     1.0  G.Hale+Chen Zhenpeng - (EDA+RAC)
# 8010    5.427800   217.0     1.0  G.Hale+Chen Zhenpeng - (EDA+RAC)
# 8011    5.097600   217.0     1.0  G.Hale+Chen Zhenpeng - (EDA+RAC)
# 8012    4.820800   217.0     1.0  G.Hale+Chen Zhenpeng - (EDA+RAC)
#
#                                 PUBREF     DATAUNC        POST   POSTUNC  \
# 0                                  NaN         inf  938.131177  0.544431
# 1                                  NaN         inf   48.639696  0.028207
# 2                                  NaN         inf   12.160772  0.004038
# 3                                  NaN         inf    9.413054  0.003676
# 4                                  NaN         inf    7.951949  0.003027
# 5                                  NaN         inf    7.010730  0.002533
# 6                                  NaN         inf    6.340275  0.001921
# 7                                  NaN         inf    5.830441  0.001880
# 8                                  NaN         inf    5.427131  0.001486
# 9                                  NaN         inf    5.096999  0.001346
# 10                                 NaN         inf    4.820209  0.001367
# 4649                         INVENT 10  568.711802  938.131177       NaN
# 4650                         INVENT 10   29.486248   48.639696       NaN
# 4651                         INVENT 10    7.372076   12.160772       NaN
# 4652                         INVENT 10    5.706361    9.413054       NaN
# 4653                         INVENT 10    4.820613    7.951949       NaN
# 4654                         INVENT 10    4.250029    7.010730       NaN
# 4655                         INVENT 10    3.843587    6.340275       NaN
# 4656                         INVENT 10    3.534517    5.830441       NaN
# 4657                         INVENT 10    3.290023    5.427131       NaN
# 4658                         INVENT 10    3.089892    5.096999       NaN
# 4659                         INVENT 10    2.922096    4.820209       NaN
# 8002  /2  6Li(n,t) Aug16;unc%=sqrt((RA    0.562879  938.131177       NaN
# 8003  /2  6Li(n,t) Aug16;unc%=sqrt((RA    0.029184   48.639696       NaN
# 8004  /2  6Li(n,t) Aug16;unc%=sqrt((RA    0.004135   12.160772       NaN
# 8005  /2  6Li(n,t) Aug16;unc%=sqrt((RA    0.003765    9.413054       NaN
# 8006  /2  6Li(n,t) Aug16;unc%=sqrt((RA    0.003101    7.951949       NaN
# 8007  /2  6Li(n,t) Aug16;unc%=sqrt((RA    0.002594    7.010730       NaN
# 8008  /2  6Li(n,t) Aug16;unc%=sqrt((RA    0.001965    6.340275       NaN
# 8009  /2  6Li(n,t) Aug16;unc%=sqrt((RA    0.001924    5.830441       NaN
# 8010  /2  6Li(n,t) Aug16;unc%=sqrt((RA    0.001520    5.427131       NaN
# 8011  /2  6Li(n,t) Aug16;unc%=sqrt((RA    0.001376    5.096999       NaN
# 8012  /2  6Li(n,t) Aug16;unc%=sqrt((RA    0.001398    4.820209       NaN
#
#       RELPOSTUNC
# 0       0.000580
# 1       0.000580
# 2       0.000332
# 3       0.000391
# 4       0.000381
# 5       0.000361
# 6       0.000303
# 7       0.000323
# 8       0.000274
# 9       0.000264
# 10      0.000284
# 4649         NaN
# 4650         NaN
# 4651         NaN
# 4652         NaN
# 4653         NaN
# 4654         NaN
# 4655         NaN
# 4656         NaN
# 4657         NaN
# 4658         NaN
# 4659         NaN
# 8002         NaN
# 8003         NaN
# 8004         NaN
# 8005         NaN
# 8006         NaN
# 8007         NaN
# 8008         NaN
# 8009         NaN
# 8010         NaN
# 8011         NaN
# 8012         NaN

# %% [markdown]
# Prepare the experimental data table

# %%
expsel = res['table']['NODE'].str.match('exp_')
expdf = res['table'].loc[expsel].copy()
expcov = res['priorcov'][np.ix_(expsel, expsel)]
expdf['UNC'] = np.sqrt(expcov.diagonal())
expdf['RELUNC'] = expdf['UNC'] / expdf['DATA']
pd.set_option("display.max_rows", 50)
expdf[expdf['REAC'] == 'MT:1-R1:1'].sort_values(by='ENERGY')
# Out:
#           NODE       REAC        ENERGY  PRIOR         UNC DESCR        DATA  \
# 4649   exp_900  MT:1-R1:1  2.530000e-08    NaN  568.711802   NaN  938.131177
# 8002  exp_2001  MT:1-R1:1  2.530000e-08    NaN    0.562879   NaN  938.525000
# 8003  exp_2001  MT:1-R1:1  9.400000e-06    NaN    0.029184   NaN   48.660000
# 4650   exp_900  MT:1-R1:1  9.400000e-06    NaN   29.486248   NaN   48.639696
# 4651   exp_900  MT:1-R1:1  1.500000e-04    NaN    7.372076   NaN   12.160772
# ...        ...        ...           ...    ...         ...   ...         ...
# 4726   exp_900  MT:1-R1:1  2.400000e+00    NaN    0.129467   NaN    0.213566
# 8080  exp_2001  MT:1-R1:1  2.600000e+00    NaN    0.010303   NaN    0.188200
# 4727   exp_900  MT:1-R1:1  2.600000e+00    NaN    0.121629   NaN    0.200636
# 4728   exp_900  MT:1-R1:1  2.800000e+00    NaN    0.111731   NaN    0.184309
# 8081  exp_2001  MT:1-R1:1  2.800000e+00    NaN    0.008755   NaN    0.169300
#
#       DB_IDX  DS_IDX                            AUTHOR  \
# 4649   107.0     0.0                             DUMMY
# 8002   217.0     1.0  G.Hale+Chen Zhenpeng - (EDA+RAC)
# 8003   217.0     1.0  G.Hale+Chen Zhenpeng - (EDA+RAC)
# 4650   107.0     0.0                             DUMMY
# 4651   107.0     0.0                             DUMMY
# ...      ...     ...                               ...
# 4726   107.0     0.0                             DUMMY
# 8080   217.0     1.0  G.Hale+Chen Zhenpeng - (EDA+RAC)
# 4727   107.0     0.0                             DUMMY
# 4728   107.0     0.0                             DUMMY
# 8081   217.0     1.0  G.Hale+Chen Zhenpeng - (EDA+RAC)
#
#                                 PUBREF     DATAUNC        POST  POSTUNC  \
# 4649                         INVENT 10  568.711802  938.131177      NaN
# 8002  /2  6Li(n,t) Aug16;unc%=sqrt((RA    0.562879  938.131177      NaN
# 8003  /2  6Li(n,t) Aug16;unc%=sqrt((RA    0.029184   48.639696      NaN
# 4650                         INVENT 10   29.486248   48.639696      NaN
# 4651                         INVENT 10    7.372076   12.160772      NaN
# ...                                ...         ...         ...      ...
# 4726                         INVENT 10    0.129467    0.213566      NaN
# 8080  /2  6Li(n,t) Aug16;unc%=sqrt((RA    0.010303    0.200636      NaN
# 4727                         INVENT 10    0.121629    0.200636      NaN
# 4728                         INVENT 10    0.111731    0.184309      NaN
# 8081  /2  6Li(n,t) Aug16;unc%=sqrt((RA    0.008755    0.184309      NaN
#
#       RELPOSTUNC    RELUNC
# 4649         NaN  0.606218
# 8002         NaN  0.000600
# 8003         NaN  0.000600
# 4650         NaN  0.606218
# 4651         NaN  0.606218
# ...          ...       ...
# 4726         NaN  0.606218
# 8080         NaN  0.054743
# 4727         NaN  0.606218
# 4728         NaN  0.606218
# 8081         NaN  0.051711
#
# [160 rows x 16 columns]

# %% [markdown]
# We remove the dummy datapoints which only act as a regularizer and have huge uncertainties---not useful for plotting

# %%
expdf = expdf.loc[~(expdf['NODE'].str.match('exp_90'))].copy()
expdf[(expdf.REAC == 'MT:1-R1:1') & (expdf.ENERGY > 0.) & (expdf.ENERGY < 0.001)]
# Out:
#           NODE       REAC        ENERGY  PRIOR       UNC DESCR      DATA  \
# 8002  exp_2001  MT:1-R1:1  2.530000e-08    NaN  0.562879   NaN  938.5250
# 8003  exp_2001  MT:1-R1:1  9.400000e-06    NaN  0.029184   NaN   48.6600
# 8004  exp_2001  MT:1-R1:1  1.500000e-04    NaN  0.004135   NaN   12.1630
# 8005  exp_2001  MT:1-R1:1  2.500000e-04    NaN  0.003765   NaN    9.4150
# 8006  exp_2001  MT:1-R1:1  3.500000e-04    NaN  0.003101   NaN    7.9535
# 8007  exp_2001  MT:1-R1:1  4.500000e-04    NaN  0.002594   NaN    7.0120
# 8008  exp_2001  MT:1-R1:1  5.500000e-04    NaN  0.001965   NaN    6.3412
# 8009  exp_2001  MT:1-R1:1  6.500000e-04    NaN  0.001924   NaN    5.8313
# 8010  exp_2001  MT:1-R1:1  7.500000e-04    NaN  0.001520   NaN    5.4278
# 8011  exp_2001  MT:1-R1:1  8.500000e-04    NaN  0.001376   NaN    5.0976
# 8012  exp_2001  MT:1-R1:1  9.500000e-04    NaN  0.001398   NaN    4.8208
#
#       DB_IDX  DS_IDX                            AUTHOR  \
# 8002   217.0     1.0  G.Hale+Chen Zhenpeng - (EDA+RAC)
# 8003   217.0     1.0  G.Hale+Chen Zhenpeng - (EDA+RAC)
# 8004   217.0     1.0  G.Hale+Chen Zhenpeng - (EDA+RAC)
# 8005   217.0     1.0  G.Hale+Chen Zhenpeng - (EDA+RAC)
# 8006   217.0     1.0  G.Hale+Chen Zhenpeng - (EDA+RAC)
# 8007   217.0     1.0  G.Hale+Chen Zhenpeng - (EDA+RAC)
# 8008   217.0     1.0  G.Hale+Chen Zhenpeng - (EDA+RAC)
# 8009   217.0     1.0  G.Hale+Chen Zhenpeng - (EDA+RAC)
# 8010   217.0     1.0  G.Hale+Chen Zhenpeng - (EDA+RAC)
# 8011   217.0     1.0  G.Hale+Chen Zhenpeng - (EDA+RAC)
# 8012   217.0     1.0  G.Hale+Chen Zhenpeng - (EDA+RAC)
#
#                                 PUBREF   DATAUNC        POST  POSTUNC  \
# 8002  /2  6Li(n,t) Aug16;unc%=sqrt((RA  0.562879  938.131177      NaN
# 8003  /2  6Li(n,t) Aug16;unc%=sqrt((RA  0.029184   48.639696      NaN
# 8004  /2  6Li(n,t) Aug16;unc%=sqrt((RA  0.004135   12.160772      NaN
# 8005  /2  6Li(n,t) Aug16;unc%=sqrt((RA  0.003765    9.413054      NaN
# 8006  /2  6Li(n,t) Aug16;unc%=sqrt((RA  0.003101    7.951949      NaN
# 8007  /2  6Li(n,t) Aug16;unc%=sqrt((RA  0.002594    7.010730      NaN
# 8008  /2  6Li(n,t) Aug16;unc%=sqrt((RA  0.001965    6.340275      NaN
# 8009  /2  6Li(n,t) Aug16;unc%=sqrt((RA  0.001924    5.830441      NaN
# 8010  /2  6Li(n,t) Aug16;unc%=sqrt((RA  0.001520    5.427131      NaN
# 8011  /2  6Li(n,t) Aug16;unc%=sqrt((RA  0.001376    5.096999      NaN
# 8012  /2  6Li(n,t) Aug16;unc%=sqrt((RA  0.001398    4.820209      NaN
#
#       RELPOSTUNC   RELUNC
# 8002         NaN  0.00060
# 8003         NaN  0.00060
# 8004         NaN  0.00034
# 8005         NaN  0.00040
# 8006         NaN  0.00039
# 8007         NaN  0.00037
# 8008         NaN  0.00031
# 8009         NaN  0.00033
# 8010         NaN  0.00028
# 8011         NaN  0.00027
# 8012         NaN  0.00029

# %% [markdown]
# ## Plot the result data

# %%
# %matplotlib notebook
# add the experimental data
curexpdf = expdf[(expdf['REAC'] == 'MT:1-R1:1') & (expdf['ENERGY'] > 0.1)]
exp_x = curexpdf['ENERGY'].to_numpy()
rng = default_rng()
exp_x = [rng.uniform(x*0.99, x*1.01, 1) for x in exp_x]
exp_y = curexpdf['DATA']
exp_unc = curexpdf['UNC']
plt.errorbar(exp_x, exp_y, yerr=exp_unc, fmt='none', ecolor='red')
# plot the evaluated curve
curdf = expdf[np.logical_and(expdf['REAC'] == 'MT:1-R1:1', expdf['ENERGY'] > 0.1)]
xvals = curdf['ENERGY']
yvals = curdf['POST']
uncs = curdf['POSTUNC']
plt.title(f'Current reaction: {resdf["DESCR"].iloc[0]}')
plt.xlabel('energy [MeV]')
plt.ylabel('cross section [barn]')
plt.errorbar(xvals, yvals, yerr=uncs)
plt.show()
