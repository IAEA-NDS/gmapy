# %%
from database_writing_utils import (extract_prior_datatable,
                                    extract_experiment_datatable)
from database_reading import read_gma_database
import numpy as np
import pandas as np

# %%
gma_database = read_gma_database('../tests/test_002/result/python/data.gma')
priordf = extract_prior_datatable(gma_database['APR'])
expdatadf = extract_experiment_datatable(gma_database['datablock_list'], priordf)

# %%
import qgrid
expdatadf.index = range(1,len(expdatadf.index)+1)
widget = qgrid.show_grid(expdatadf)
widget
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…

# %%
df = expdatadf.copy()
df.drop(columns=['energy','measurement'], inplace=True)
df.drop_duplicates(inplace=True)
df.index = range(1,len(df.index)+1)
widget = qgrid.show_grid(df)
widget
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…

# %%
num_xsids = priordf['xsid'].nunique()
sorted_df = priordf.sort_values(by='xsid')
for xsid in range(1, num_xsids+1):
    curdf = sorted_df[sorted_df.xsid == xsid]
    curdf.sort_values(by='energy', inplace=True)
    for cur_ro
# Out:
#     xsid      reac        energy        xs
# 0      1  6Li(n,a)  2.530000e-08  938.1000
# 1      1  6Li(n,a)  9.400000e-06   48.6400
# 2      1  6Li(n,a)  1.500000e-04   12.1600
# 3      1  6Li(n,a)  2.500000e-04    9.4130
# 4      1  6Li(n,a)  3.500000e-04    7.9540
# ..   ...       ...           ...       ...
# 75     1  6Li(n,a)  2.000000e+00    0.2193
# 76     1  6Li(n,a)  2.200000e+00    0.2145
# 77     1  6Li(n,a)  2.400000e+00    0.2069
# 78     1  6Li(n,a)  2.600000e+00    0.1861
# 79     1  6Li(n,a)  2.800000e+00    0.1685
#
# [80 rows x 4 columns]
#     xsid      reac        energy      xs
# 0      2  6Li(n,n)  2.530000e-08  0.6891
# 1      2  6Li(n,n)  9.400000e-06  0.6889
# 2      2  6Li(n,n)  1.500000e-04  0.6882
# 3      2  6Li(n,n)  2.500000e-04  0.6879
# 4      2  6Li(n,n)  3.500000e-04  0.6876
# ..   ...       ...           ...     ...
# 75     2  6Li(n,n)  2.000000e+00  1.1320
# 76     2  6Li(n,n)  2.200000e+00  1.2120
# 77     2  6Li(n,n)  2.400000e+00  1.3030
# ...
